# %% [markdown]
# ## 1-D Transiet heat diffusion solver with Physics Informed Neural Networks

# %% [markdown]
# **Import the libraries**

# %%
## Import basic numerical and plotting packages ##
from utils.importer import *

## Import the numerical PDE solver ##
from utils.numericalSolver import NumPDE

# ## Import the neural network dataprocessor and framework ##
from utils.PINN import DataPreprocessor, PINN

# %% [markdown]
# **Setup the calculation details**

# %% [markdown]
# The governing equation is by,

# %% [markdown]
# $$\frac{\partial T}{\partial t} = \frac{\partial^2 T}{\partial x^2}$$

# %% [markdown]
# The domain and time range is defined as follows,

# %% [markdown]
# $$\forall \, x \in (0,l) \text{ and } 0 < t < t_{range}$$

# %% [markdown]
# Initial conditions are as follows,

# %% [markdown]
# $$T(x, 0) = 0 $$

# %% [markdown]
# Boundary conditions are defined as,

# %% [markdown]
# $$ \left.\frac{\partial T}{\partial x}\right\vert_{(0,t)} = 0 \text{ and } \left. T \right\vert_{(l,t)} = sin(t)$$

# %%
## total time of simulation and length of the system ##
trange, l = 2*np.pi, 1

## Package the time and spatial domain ##
extent = [[0, l], [0, trange]]

## Specify time and space discretizations ##
nx, nt = 256, 100

## Specify how much of available training data will be randomly picked for training in the domain, IC and BCs##
frac = {'ic': 0.8, 'bc': 0.8, 'dom' : 0.8}

## Specify the number of random points in the domain to evaluate PDE loss
N_f = 10000

## Neural Network structure ##
    ## Two inputs (x and t) and one output (temperature)
layers = [2, 20, 20, 20, 20, 20, 20, 20, 20, 1]

## Initialize the 1-D grid for the numerical solver ##
grid = CartesianGrid([[0, l]], nx)  

## Setup the initial condition of the system ##
    ## For the current problem it is set at 0 ##
field = ScalarField(grid, 0)        

## Definition of the diffusion PDE ##
    ## Specify diffusivity of the domain ##
diffusivity = 0.1
    ## Define the rhs of differential equation ##
rhs = f"(({diffusivity}) * laplace(c))"
    ## Specify the boundary conditions, first left end and then right end ##
bc = [[{'derivative':0}, {'value_expression':'sin(t)'}]]
    ## package thegoverning equation and boundary conditions ##
eq = PDE({"c": f"{rhs}"}, bc=bc)

# %% [markdown]
# **Obtain the numerical solution**

# %%
## Obtain the numerical solution ##
    ## We use explicit RK-4 adaptive time stepping ##
    ## Also specified the time discretization  using the variable nt ##
if os.path.isfile('saved/numSol.pkl'):
    with open('saved/numSol.pkl', 'rb') as file:
        numSol = pkl.load(file)
else:
    numSol = NumPDE(eq, grid, field, 'Explicit', trange, trange/nt).ground_truth

# %% [markdown]
# **Create the NN data from numerical solution**

# %%
NNdata = DataPreprocessor(numSol, frac, extent, N_f)

# %% [markdown]
# **Setup the NN, train and save the weights**

# %%
model = PINN(NNdata, layers, diffusivity, 10000, 100)
if os.path.isfile('saved/best_model'):
    model.dnn.load_state_dict(torch.load('saved/best_model', map_location=torch.device('cpu')))
else:
    model.train()
# Out:
# Iter 100, Loss train: 3.05622e-01, Loss test: 6.79895e-02
# Iter 200, Loss train: 1.13584e-01, Loss test: 1.23422e-02
# Iter 300, Loss train: 8.50309e-02, Loss test: 7.43211e-03
# Iter 400, Loss train: 7.10723e-02, Loss test: 4.91061e-03
# Iter 500, Loss train: 6.05373e-02, Loss test: 4.15165e-03
# Iter 600, Loss train: 5.18444e-02, Loss test: 3.13785e-03
# Iter 700, Loss train: 4.43426e-02, Loss test: 2.73473e-03
# Iter 800, Loss train: 3.78374e-02, Loss test: 2.14495e-03
# Iter 900, Loss train: 3.29293e-02, Loss test: 1.86652e-03
# Iter 1000, Loss train: 2.91867e-02, Loss test: 1.61314e-03
# Iter 1100, Loss train: 2.63675e-02, Loss test: 1.45165e-03
# Iter 1200, Loss train: 2.82016e-02, Loss test: 7.33366e-03
# Iter 1300, Loss train: 2.17185e-02, Loss test: 1.26517e-03
# Iter 1400, Loss train: 2.07811e-02, Loss test: 1.35714e-03
# Iter 1500, Loss train: 1.88086e-02, Loss test: 1.12885e-03
# Iter 1600, Loss train: 1.79207e-02, Loss test: 1.05726e-03
# Iter 1700, Loss train: 1.69358e-02, Loss test: 1.03098e-03
# Iter 1800, Loss train: 1.63550e-02, Loss test: 1.00172e-03
# Iter 1900, Loss train: 1.55327e-02, Loss test: 9.55861e-04
# Iter 2000, Loss train: 1.51530e-02, Loss test: 9.51670e-04
# Iter 2100, Loss train: 1.43425e-02, Loss test: 8.93281e-04
# Iter 2200, Loss train: 1.36704e-02, Loss test: 8.61295e-04
# Iter 2300, Loss train: 1.33726e-02, Loss test: 8.38619e-04
# Iter 2400, Loss train: 1.26914e-02, Loss test: 8.10975e-04
# Iter 2500, Loss train: 1.20676e-02, Loss test: 7.81375e-04
# Iter 2600, Loss train: 1.20923e-02, Loss test: 8.11378e-04
# Iter 2700, Loss train: 1.10671e-02, Loss test: 7.30962e-04
# Iter 2800, Loss train: 1.04538e-02, Loss test: 7.02027e-04
# Iter 2900, Loss train: 1.01968e-02, Loss test: 7.06863e-04
# Iter 3000, Loss train: 9.55397e-03, Loss test: 6.57182e-04
# Iter 3100, Loss train: 8.96294e-03, Loss test: 6.29047e-04
# Iter 3200, Loss train: 8.70623e-03, Loss test: 6.28724e-04
# Iter 3300, Loss train: 8.08490e-03, Loss test: 5.85973e-04
# Iter 3400, Loss train: 1.67423e-02, Loss test: 1.98084e-03
# Iter 3500, Loss train: 7.32558e-03, Loss test: 5.46179e-04
# Iter 3600, Loss train: 6.80310e-03, Loss test: 5.21899e-04
# Iter 3700, Loss train: 1.08512e-02, Loss test: 1.24560e-03
# Iter 3800, Loss train: 6.19774e-03, Loss test: 4.87178e-04
# Iter 3900, Loss train: 5.76109e-03, Loss test: 4.64075e-04
# Iter 4000, Loss train: 5.70833e-03, Loss test: 4.40497e-04
# Iter 4100, Loss train: 5.21563e-03, Loss test: 4.30792e-04
# Iter 4200, Loss train: 6.68389e-03, Loss test: 6.60582e-04
# Iter 4300, Loss train: 4.76840e-03, Loss test: 3.96270e-04
# Iter 4400, Loss train: 5.49327e-03, Loss test: 2.35962e-03
# Iter 4500, Loss train: 4.47030e-03, Loss test: 3.70300e-04
# Iter 4600, Loss train: 4.26141e-03, Loss test: 3.53364e-04
# Iter 4700, Loss train: 4.38865e-03, Loss test: 3.62266e-04
# Iter 4800, Loss train: 6.01517e-03, Loss test: 2.69629e-03
# Iter 4900, Loss train: 3.90805e-03, Loss test: 3.18877e-04
# Iter 5000, Loss train: 5.33949e-03, Loss test: 6.22118e-04
# Iter 5100, Loss train: 3.71319e-03, Loss test: 2.99545e-04
# Iter 5200, Loss train: 3.58752e-03, Loss test: 2.87215e-04
# Iter 5300, Loss train: 3.58881e-03, Loss test: 2.87918e-04
# Iter 5400, Loss train: 3.43097e-03, Loss test: 2.70419e-04
# Iter 5500, Loss train: 9.50125e-03, Loss test: 1.73462e-03
# Iter 5600, Loss train: 3.27679e-03, Loss test: 2.53732e-04
# Iter 5700, Loss train: 5.22764e-03, Loss test: 6.57425e-04
# Iter 5800, Loss train: 3.14102e-03, Loss test: 2.38862e-04
# Iter 5900, Loss train: 3.06016e-03, Loss test: 2.35579e-04
# Iter 6000, Loss train: 3.03651e-03, Loss test: 2.25253e-04
# Iter 6100, Loss train: 2.93525e-03, Loss test: 2.16130e-04
# Iter 6200, Loss train: 8.62771e-03, Loss test: 1.28729e-03
# Iter 6300, Loss train: 2.83177e-03, Loss test: 2.03622e-04
# Iter 6400, Loss train: 2.75823e-03, Loss test: 1.97027e-04
# Iter 6500, Loss train: 2.75374e-03, Loss test: 1.95539e-04
# Iter 6600, Loss train: 2.66587e-03, Loss test: 1.85779e-04
# Iter 6700, Loss train: 7.31177e-03, Loss test: 3.56880e-03
# Iter 6800, Loss train: 2.58766e-03, Loss test: 1.76217e-04
# Iter 6900, Loss train: 2.51774e-03, Loss test: 1.69356e-04
# Iter 7000, Loss train: 2.73756e-03, Loss test: 2.52810e-04
# Iter 7100, Loss train: 2.44318e-03, Loss test: 1.58961e-04
# Iter 7200, Loss train: 2.84646e-03, Loss test: 2.44965e-04
# Iter 7300, Loss train: 2.57307e-03, Loss test: 2.94445e-04
# Iter 7400, Loss train: 2.31189e-03, Loss test: 1.48697e-04
# Iter 7500, Loss train: 5.14634e-03, Loss test: 1.76302e-03
# Iter 7600, Loss train: 2.23498e-03, Loss test: 1.40774e-04
# Iter 7700, Loss train: 2.26295e-03, Loss test: 1.41485e-04
# Iter 7800, Loss train: 2.17976e-03, Loss test: 1.46936e-04
# Iter 7900, Loss train: 2.67814e-03, Loss test: 1.69354e-03
# Iter 8000, Loss train: 2.09102e-03, Loss test: 1.27331e-04
# Iter 8100, Loss train: 2.20365e-03, Loss test: 1.71808e-04
# Iter 8200, Loss train: 4.86746e-03, Loss test: 1.45281e-03
# Iter 8300, Loss train: 1.99791e-03, Loss test: 1.18618e-04
# Iter 8400, Loss train: 2.30094e-03, Loss test: 1.86191e-04
# Iter 8500, Loss train: 1.93112e-03, Loss test: 1.13299e-04
# Iter 8600, Loss train: 1.93633e-03, Loss test: 1.16287e-04
# Iter 8700, Loss train: 1.71936e-02, Loss test: 6.92916e-03
# Iter 8800, Loss train: 1.84772e-03, Loss test: 1.06661e-04
# Iter 8900, Loss train: 2.17128e-03, Loss test: 1.94998e-04
# Iter 9000, Loss train: 1.78829e-03, Loss test: 1.02059e-04
# Iter 9100, Loss train: 1.80146e-03, Loss test: 1.10123e-04
# Iter 9200, Loss train: 2.70544e-03, Loss test: 1.77290e-03
# Iter 9300, Loss train: 1.71628e-03, Loss test: 9.66797e-05
# Iter 9400, Loss train: 1.14830e-02, Loss test: 9.10312e-04
# Iter 9500, Loss train: 1.66907e-03, Loss test: 9.40539e-05
# Iter 9600, Loss train: 1.63287e-03, Loss test: 8.99118e-05
# Iter 9700, Loss train: 1.64625e-03, Loss test: 9.28165e-05
# Iter 9800, Loss train: 1.58855e-03, Loss test: 8.66910e-05
# Iter 9900, Loss train: 1.57560e-03, Loss test: 8.74785e-05
# Iter 10000, Loss train: 1.53692e-03, Loss test: 8.30083e-05

# %% [markdown]
# **Run the predictions**

# %%
model.predict(NNdata, [0.2, 0.50, 0.8], extent)
# Out:
# Total average error on the prediction w.r.t ground truth = 0.00667751591222151
