# %% [markdown]
# **Import the libraries**

# %%
from utils.importer import *
from utils.numericalSolver import NumPDE
from utils.dataNN import DataPreprocessor, DataBasedNN

# %%
## total time
trange, l = 2*np.pi, 1
extent = [[0, l], [0, trange]]

## discretizations
nx, nt = 256, 100

## Specify the test train split
split = 0.7

## Specify how much of available training data will be randomly picked
frac = 0.8

## Neural net structure
layers = [2, 20, 20, 20, 20, 20, 20, 20, 20, 1]

## initialize the grid, an initial condition, and the PDE
grid = CartesianGrid([[0, l]], nx)  # generate grid
field = ScalarField(grid, 0)        # generate initial condition

## Expanded definition of the PDE
diffusivity = 0.1
rhs = f"(({diffusivity}) * laplace(c))"#" + cos(t)"
bc = [[{'derivative':0}, {'value_expression':'sin(t)'}]]
eq = PDE({"c": f"{rhs}"}, bc=bc)

## Obtain the numerical solution
numSol = NumPDE(eq, grid, field, 'Explicit', trange, trange/nt)

## Prepare the dataset for training
NNdata = DataPreprocessor(numSol.ground_truth, split, frac, extent)

# %% [markdown]
# **Object for numerical solver**

# %% [markdown]
# **Object for creating datasets for NN**

# %% [markdown]
# **Create Neural Net**

# %% [markdown]
# **Create Data based NN**

# %% [markdown]
# **System details**

# %%
model = DataBasedNN(NNdata.data, layers)
# model.train()
# torch.save(model.dnn.state_dict(), 'utils/trained_parameters')

model.dnn.load_state_dict(torch.load('utils/trained_parameters'))
model.predict(NNdata, [0.25, 0.50, 0.75], split, extent)
