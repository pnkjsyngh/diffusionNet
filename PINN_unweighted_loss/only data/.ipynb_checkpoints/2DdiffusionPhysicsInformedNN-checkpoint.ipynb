# %% [markdown]
# ## 1-D Transiet heat diffusion solver with Physics Informed Neural Networks

# %% [markdown]
# **Import the libraries**

# %%
## Import basic numerical and plotting packages ##
from utils.importer import *

## Import the numerical PDE solver ##
from utils.numericalSolver import NumPDE

# ## Import the neural network dataprocessor and framework ##
from utils.PINN import DataPreprocessor, PINN

# %% [markdown]
# **Setup the calculation details**

# %% [markdown]
# The governing equation is by,

# %% [markdown]
# $$\frac{\partial T}{\partial t} = \frac{\partial^2 T}{\partial x^2}$$

# %% [markdown]
# The domain and time range is defined as follows,

# %% [markdown]
# $$\forall \, x \in (0,l) \text{ and } 0 < t < t_{range}$$

# %% [markdown]
# Initial conditions are as follows,

# %% [markdown]
# $$T(x, 0) = 0 $$

# %% [markdown]
# Boundary conditions are defined as,

# %% [markdown]
# $$ \left.\frac{\partial T}{\partial x}\right\vert_{(0,t)} = 0 \text{ and } \left. T \right\vert_{(l,t)} = sin(t)$$

# %%
## total time of simulation and length of the system ##
trange, l = 2*np.pi, 1

## Package the time and spatial domain ##
extent = [[0, l], [0, trange]]

## Specify time and space discretizations ##
nx, nt = 256, 100

## Specify how much of available training data will be randomly picked for training in the domain, IC and BCs##
frac = {'ic': 0.8, 'bc': 0.8, 'dom' : 0.8}

## Specify the number of random points in the domain to evaluate PDE loss
N_f = 1

## Neural Network structure ##
    ## Two inputs (x and t) and one output (temperature)
layers = [2, 20, 20, 20, 20, 20, 20, 20, 20, 1]

## Initialize the 1-D grid for the numerical solver ##
grid = CartesianGrid([[0, l]], nx)  

## Setup the initial condition of the system ##
    ## For the current problem it is set at 0 ##
field = ScalarField(grid, 0)        

## Definition of the diffusion PDE ##
    ## Specify diffusivity of the domain ##
diffusivity = 0.1
    ## Define the rhs of differential equation ##
rhs = f"(({diffusivity}) * laplace(c))"
    ## Specify the boundary conditions, first left end and then right end ##
bc = [[{'derivative':0}, {'value_expression':'sin(t)'}]]
    ## package thegoverning equation and boundary conditions ##
eq = PDE({"c": f"{rhs}"}, bc=bc)

# %% [markdown]
# **Obtain the numerical solution**

# %%
## Obtain the numerical solution ##
    ## We use explicit RK-4 adaptive time stepping ##
    ## Also specified the time discretization  using the variable nt ##
if os.path.isfile('saved/numSol.pkl'):
    with open('saved/numSol.pkl', 'rb') as file:
        numSol = pkl.load(file)
else:
    numSol = NumPDE(eq, grid, field, 'Explicit', trange, trange/nt).ground_truth

# %% [markdown]
# **Create the NN data from numerical solution**

# %%
NNdata = DataPreprocessor(numSol, frac, extent, N_f)

# %% [markdown]
# **Setup the NN, train and save the weights**

# %%
model = PINN(NNdata, layers, diffusivity, 10000, 100)
if os.path.isfile('saved/best_model'):
    model.dnn.load_state_dict(torch.load('saved/best_model', map_location=torch.device('cpu')))
else:
    model.train()
# Out:
# Iter 100, Loss train: 2.29956e-01, Loss test: 9.59323e-02
# Iter 200, Loss train: 1.16992e-01, Loss test: 5.11479e-02
# Iter 300, Loss train: 4.40644e-02, Loss test: 1.47175e-02
# Iter 400, Loss train: 3.67905e-02, Loss test: 1.20056e-02
# Iter 500, Loss train: 2.72541e-02, Loss test: 9.06435e-03
# Iter 600, Loss train: 1.72789e-02, Loss test: 8.11823e-03
# Iter 700, Loss train: 1.03646e-02, Loss test: 6.22363e-03
# Iter 800, Loss train: 7.42061e-03, Loss test: 4.77951e-03
# Iter 900, Loss train: 6.04669e-03, Loss test: 3.86299e-03
# Iter 1000, Loss train: 4.98488e-03, Loss test: 3.31255e-03
# Iter 1100, Loss train: 4.15705e-03, Loss test: 3.21645e-03
# Iter 1200, Loss train: 4.01265e-03, Loss test: 3.39070e-03
# Iter 1300, Loss train: 3.41572e-03, Loss test: 2.73715e-03
# Iter 1400, Loss train: 3.14604e-03, Loss test: 2.59123e-03
# Iter 1500, Loss train: 2.96274e-03, Loss test: 2.38592e-03
# Iter 1600, Loss train: 3.82781e-03, Loss test: 2.22514e-03
# Iter 1700, Loss train: 3.00021e-03, Loss test: 2.72247e-03
# Iter 1800, Loss train: 2.51116e-03, Loss test: 2.08141e-03
# Iter 1900, Loss train: 3.29659e-03, Loss test: 2.90546e-03
# Iter 2000, Loss train: 6.71158e-03, Loss test: 2.97065e-03
# Iter 2100, Loss train: 2.12040e-03, Loss test: 1.83792e-03
# Iter 2200, Loss train: 2.04436e-03, Loss test: 1.80781e-03
# Iter 2300, Loss train: 3.32288e-03, Loss test: 1.74101e-03
# Iter 2400, Loss train: 2.26145e-03, Loss test: 2.02078e-03
# Iter 2500, Loss train: 1.78642e-03, Loss test: 1.51598e-03
# Iter 2600, Loss train: 1.71058e-03, Loss test: 1.46382e-03
# Iter 2700, Loss train: 1.64826e-03, Loss test: 1.42180e-03
# Iter 2800, Loss train: 1.59068e-03, Loss test: 1.32316e-03
# Iter 2900, Loss train: 1.51254e-03, Loss test: 1.30157e-03
# Iter 3000, Loss train: 1.45728e-03, Loss test: 1.26080e-03
# Iter 3100, Loss train: 1.39797e-03, Loss test: 1.20545e-03
# Iter 3200, Loss train: 1.32985e-03, Loss test: 1.13230e-03
# Iter 3300, Loss train: 1.27886e-03, Loss test: 1.07543e-03
# Iter 3400, Loss train: 1.24317e-03, Loss test: 1.02380e-03
# Iter 3500, Loss train: 1.56567e-03, Loss test: 1.02805e-03
# Iter 3600, Loss train: 1.14810e-03, Loss test: 9.31709e-04
# Iter 3700, Loss train: 1.08681e-03, Loss test: 9.12905e-04
# Iter 3800, Loss train: 1.07904e-03, Loss test: 8.58026e-04
# Iter 3900, Loss train: 1.05786e-03, Loss test: 9.09040e-04
# Iter 4000, Loss train: 9.67192e-04, Loss test: 8.02620e-04
# Iter 4100, Loss train: 1.13843e-03, Loss test: 8.39180e-04
# Iter 4200, Loss train: 8.94604e-04, Loss test: 7.42598e-04
# Iter 4300, Loss train: 8.66081e-04, Loss test: 7.04247e-04
# Iter 4400, Loss train: 1.14285e-03, Loss test: 7.82754e-04
# Iter 4500, Loss train: 8.03220e-04, Loss test: 6.53038e-04
# Iter 4600, Loss train: 1.23969e-03, Loss test: 1.07196e-03
# Iter 4700, Loss train: 7.48285e-04, Loss test: 6.03617e-04
# Iter 4800, Loss train: 7.52464e-04, Loss test: 5.98071e-04
# Iter 4900, Loss train: 6.98296e-04, Loss test: 5.59758e-04
# Iter 5000, Loss train: 7.71056e-04, Loss test: 5.59761e-04
# Iter 5100, Loss train: 6.53249e-04, Loss test: 5.18442e-04
# Iter 5200, Loss train: 7.14967e-04, Loss test: 5.32673e-04
# Iter 5300, Loss train: 6.12399e-04, Loss test: 4.81933e-04
# Iter 5400, Loss train: 6.00847e-04, Loss test: 4.75871e-04
# Iter 5500, Loss train: 5.74842e-04, Loss test: 4.48564e-04
# Iter 5600, Loss train: 5.68065e-04, Loss test: 4.31310e-04
# Iter 5700, Loss train: 2.40723e-03, Loss test: 1.38887e-03
# Iter 5800, Loss train: 5.26926e-04, Loss test: 4.03540e-04
# Iter 5900, Loss train: 5.56457e-04, Loss test: 3.96556e-04
# Iter 6000, Loss train: 4.98099e-04, Loss test: 3.79134e-04
# Iter 6100, Loss train: 5.03621e-04, Loss test: 3.63802e-04
# Iter 6200, Loss train: 4.74206e-04, Loss test: 3.55766e-04
# Iter 6300, Loss train: 4.66828e-04, Loss test: 3.47439e-04
# Iter 6400, Loss train: 4.51762e-04, Loss test: 3.38244e-04
# Iter 6500, Loss train: 4.54016e-04, Loss test: 3.27358e-04
# Iter 6600, Loss train: 4.33823e-04, Loss test: 3.22354e-04
# Iter 6700, Loss train: 4.27839e-04, Loss test: 3.13621e-04
# Iter 6800, Loss train: 4.20414e-04, Loss test: 3.06353e-04
# Iter 6900, Loss train: 4.30334e-04, Loss test: 3.06246e-04
# Iter 7000, Loss train: 4.02514e-04, Loss test: 2.96385e-04
# Iter 7100, Loss train: 4.00846e-04, Loss test: 2.87886e-04
# Iter 7200, Loss train: 1.14175e-03, Loss test: 7.63233e-04
# Iter 7300, Loss train: 3.85807e-04, Loss test: 2.81406e-04
# Iter 7400, Loss train: 3.92678e-04, Loss test: 2.88846e-04
# Iter 7500, Loss train: 3.75175e-04, Loss test: 2.74335e-04
# Iter 7600, Loss train: 3.81833e-04, Loss test: 2.71040e-04
# Iter 7700, Loss train: 3.84430e-04, Loss test: 2.76045e-04
# Iter 7800, Loss train: 2.59146e-03, Loss test: 5.21305e-04
# Iter 7900, Loss train: 3.58000e-04, Loss test: 2.61005e-04
# Iter 8000, Loss train: 3.73255e-04, Loss test: 2.63418e-04
# Iter 8100, Loss train: 3.51710e-04, Loss test: 2.55465e-04
# Iter 8200, Loss train: 3.54602e-04, Loss test: 2.54051e-04
# Iter 8300, Loss train: 2.04255e-03, Loss test: 8.08790e-04
# Early stopped training at epoch 8317

# %% [markdown]
# **Run the predictions**

# %%
model.predict(NNdata, [0.2, 0.50, 0.8], extent)
# Out:
# Total average error on the prediction w.r.t ground truth = 0.012660328547014169
