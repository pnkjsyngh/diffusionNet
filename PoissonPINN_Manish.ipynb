# %% [markdown]
# <a href="https://colab.research.google.com/github/pnkjsyngh/pinn-poisson/blob/main/PoissonPINN_Manish.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## Import the packages ##

import os
import numpy as np

## Make sure change this on your end ##
os.chdir('/content/drive/MyDrive/Colab Notebooks/PINNs/Poisson')
## --------------------------------- ##

from utils.poissonsolver import PoissonSolver

# %%
## generate the numerical solution ##
numerical_sol = PoissonSolver('cos(y)/4', 2*np.pi, 128,
                    [[{'value':0}, {'value':1}],
                     [{'derivative':0}, {'derivative':0}]])
numerical_sol.solve()
numerical_sol.result.plot()
